# %% [markdown]
# # Run MCMC for JIMWLK

# %%
from src import workdir, parse_model_parameter_file
from src.emulator_BAND import EmulatorBAND
from src.mcmc import Chain

import dill
import os
import pickle

# %%
exp_path = "./exp_data_JIMWLK.pkl"
model_par = "./IP_DIFF_JIMWLK_prior_range_delete_unused"
mymcmc = Chain(expdata_path=exp_path, model_parafile=model_par)
# Out:
# [INFO][mcmc] Initializing MCMC ...
# [INFO][mcmc] Final Markov Chain results will be saved in mcmc/chain.pkl
# [INFO][mcmc] Loading the model parameters space from ./IP_DIFF_JIMWLK_prior_range_delete_unused ...
# [INFO][mcmc] Run MCMC with emcee...
# [INFO][mcmc] Loading the experiment data from ./exp_data_JIMWLK.pkl ...
# [INFO][mcmc] Experimental dataset size: 73

# %%
emuPathList = ["./emulator.pkl"]
mymcmc.loadEmulator(emuPathList)
# Out:
# [INFO][mcmc] Number of Emulators: 1

# %%
os.environ["OMP_NUM_THREADS"] = "1"
# may have to: export RDMAV_FORK_SAFE=1 before running the code
n_effective=800
n_active=400
n_prior=1600
sample="tpcn"
n_max_steps=100
random_state=42

n_total = 5000
n_evidence = 5000

pool = 12

sampler = mymcmc.run_pocoMC(n_effective=n_effective, n_active=n_active,
                            n_prior=n_prior, sample=sample,
                            n_max_steps=n_max_steps, random_state=random_state,
                            n_total=n_total, n_evidence=n_evidence, pool=pool)
# Out:
# [INFO][mcmc] Generate the prior class for pocoMC ...
# [INFO][mcmc] Starting pocoMC ...
# Iter: 0it [00:00, ?it/s]
# Iter: 0it [00:00, ?it/s, beta=0, calls=0, ESS=800, logZ=0, logP=0, acc=0, steps=0, eff=0]
# Iter: 0it [00:00, ?it/s, beta=0, calls=400, ESS=800, logZ=0, logP=-3.02e+299, acc=1, steps=1, eff=1]
# Iter: 1it [00:00,  2.20it/s, beta=0, calls=400, ESS=800, logZ=0, logP=-3.02e+299, acc=1, steps=1, eff=1]
# Iter: 1it [00:00,  2.20it/s, beta=0, calls=800, ESS=800, logZ=0, logP=-3.47e+299, acc=1, steps=1, eff=1]
# Iter: 2it [00:00,  2.43it/s, beta=0, calls=800, ESS=800, logZ=0, logP=-3.47e+299, acc=1, steps=1, eff=1]
# Iter: 2it [00:01,  2.43it/s, beta=0, calls=1200, ESS=800, logZ=0, logP=-3.37e+299, acc=1, steps=1, eff=1]
# Iter: 3it [00:01,  2.37it/s, beta=0, calls=1200, ESS=800, logZ=0, logP=-3.37e+299, acc=1, steps=1, eff=1]
# Iter: 3it [00:01,  2.37it/s, beta=0, calls=1600, ESS=800, logZ=0, logP=-3.35e+299, acc=1, steps=1, eff=1]
# Iter: 4it [00:01,  2.46it/s, beta=0, calls=1600, ESS=800, logZ=0, logP=-3.35e+299, acc=1, steps=1, eff=1]
# Iter: 5it [00:01,  2.46it/s, beta=0.0312, calls=1600, ESS=803, logZ=-12.8, logP=-3.35e+299, acc=1, steps=1, eff=1]
# Iter: 5it [00:04,  2.46it/s, beta=0.0312, calls=2000, ESS=803, logZ=-12.8, logP=-398, acc=0.518, steps=1, eff=1]
# Iter: 5it [00:05,  2.46it/s, beta=0.0312, calls=2400, ESS=803, logZ=-12.8, logP=-400, acc=0.474, steps=2, eff=1]
# Iter: 5it [00:05,  2.46it/s, beta=0.0312, calls=2800, ESS=803, logZ=-12.8, logP=-399, acc=0.52, steps=3, eff=1]
# Iter: 5it [00:06,  2.46it/s, beta=0.0312, calls=3200, ESS=803, logZ=-12.8, logP=-399, acc=0.474, steps=4, eff=1]
# Iter: 6it [00:06,  1.48s/it, beta=0.0312, calls=3200, ESS=803, logZ=-12.8, logP=-399, acc=0.474, steps=4, eff=1]
# Iter: 6it [00:06,  1.48s/it, beta=0.0729, calls=3200, ESS=802, logZ=-28.9, logP=-399, acc=0.474, steps=4, eff=1]
# Iter: 6it [00:08,  1.48s/it, beta=0.0729, calls=3600, ESS=802, logZ=-28.9, logP=-390, acc=0.44, steps=1, eff=1]
# Iter: 6it [00:08,  1.48s/it, beta=0.0729, calls=4000, ESS=802, logZ=-28.9, logP=-391, acc=0.414, steps=2, eff=1]
# Iter: 6it [00:09,  1.48s/it, beta=0.0729, calls=4400, ESS=802, logZ=-28.9, logP=-391, acc=0.407, steps=3, eff=1]
# Iter: 6it [00:10,  1.48s/it, beta=0.0729, calls=4800, ESS=802, logZ=-28.9, logP=-391, acc=0.397, steps=4, eff=1]
# Iter: 7it [00:10,  2.08s/it, beta=0.0729, calls=4800, ESS=802, logZ=-28.9, logP=-391, acc=0.397, steps=4, eff=1]
# Iter: 7it [00:10,  2.08s/it, beta=0.125, calls=4800, ESS=795, logZ=-48.9, logP=-391, acc=0.397, steps=4, eff=1]
# Iter: 7it [00:12,  2.08s/it, beta=0.125, calls=5200, ESS=795, logZ=-48.9, logP=-387, acc=0.407, steps=1, eff=1]
# Iter: 7it [00:13,  2.08s/it, beta=0.125, calls=5600, ESS=795, logZ=-48.9, logP=-387, acc=0.37, steps=2, eff=1]
# Iter: 7it [00:13,  2.08s/it, beta=0.125, calls=6000, ESS=795, logZ=-48.9, logP=-387, acc=0.401, steps=3, eff=1]
# Iter: 7it [00:14,  2.08s/it, beta=0.125, calls=6400, ESS=795, logZ=-48.9, logP=-387, acc=0.362, steps=4, eff=1]
# Iter: 8it [00:14,  2.67s/it, beta=0.125, calls=6400, ESS=795, logZ=-48.9, logP=-387, acc=0.362, steps=4, eff=1]
# Iter: 8it [00:14,  2.67s/it, beta=0.192, calls=6400, ESS=799, logZ=-74.1, logP=-387, acc=0.362, steps=4, eff=1]
# Iter: 8it [00:17,  2.67s/it, beta=0.192, calls=6800, ESS=799, logZ=-74.1, logP=-383, acc=0.357, steps=1, eff=1]
# Iter: 8it [00:18,  2.67s/it, beta=0.192, calls=7200, ESS=799, logZ=-74.1, logP=-383, acc=0.36, steps=2, eff=1]
# Iter: 8it [00:19,  2.67s/it, beta=0.192, calls=7600, ESS=799, logZ=-74.1, logP=-383, acc=0.309, steps=3, eff=1]
# Iter: 8it [00:19,  2.67s/it, beta=0.192, calls=8000, ESS=799, logZ=-74.1, logP=-384, acc=0.3, steps=4, eff=1]
# Iter: 9it [00:19,  3.45s/it, beta=0.192, calls=8000, ESS=799, logZ=-74.1, logP=-384, acc=0.3, steps=4, eff=1]
# Iter: 9it [00:19,  3.45s/it, beta=0.274, calls=8000, ESS=792, logZ=-105, logP=-384, acc=0.3, steps=4, eff=1]
# Iter: 9it [00:21,  3.45s/it, beta=0.274, calls=8400, ESS=792, logZ=-105, logP=-381, acc=0.287, steps=1, eff=1]
# Iter: 9it [00:22,  3.45s/it, beta=0.274, calls=8800, ESS=792, logZ=-105, logP=-381, acc=0.301, steps=2, eff=1]
# Iter: 9it [00:23,  3.45s/it, beta=0.274, calls=9200, ESS=792, logZ=-105, logP=-381, acc=0.224, steps=3, eff=0.996]
# Iter: 9it [00:23,  3.45s/it, beta=0.274, calls=9600, ESS=792, logZ=-105, logP=-381, acc=0.262, steps=4, eff=1]
# Iter: 10it [00:23,  3.62s/it, beta=0.274, calls=9600, ESS=792, logZ=-105, logP=-381, acc=0.262, steps=4, eff=1]
# Iter: 10it [00:23,  3.62s/it, beta=0.365, calls=9600, ESS=805, logZ=-139, logP=-381, acc=0.262, steps=4, eff=1]
# Iter: 10it [00:28,  3.62s/it, beta=0.365, calls=1e+4, ESS=805, logZ=-139, logP=-379, acc=0.286, steps=1, eff=1]
# Iter: 10it [00:28,  3.62s/it, beta=0.365, calls=10400, ESS=805, logZ=-139, logP=-379, acc=0.29, steps=2, eff=1]
# Iter: 10it [00:29,  3.62s/it, beta=0.365, calls=10800, ESS=805, logZ=-139, logP=-379, acc=0.26, steps=3, eff=1]
# Iter: 10it [00:30,  3.62s/it, beta=0.365, calls=11200, ESS=805, logZ=-139, logP=-380, acc=0.24, steps=4, eff=1]
# Iter: 11it [00:30,  4.44s/it, beta=0.365, calls=11200, ESS=805, logZ=-139, logP=-380, acc=0.24, steps=4, eff=1]
# Iter: 11it [00:30,  4.44s/it, beta=0.467, calls=11200, ESS=800, logZ=-176, logP=-380, acc=0.24, steps=4, eff=1]
# Iter: 11it [00:33,  4.44s/it, beta=0.467, calls=11600, ESS=800, logZ=-176, logP=-377, acc=0.283, steps=1, eff=1]
# Iter: 11it [00:34,  4.44s/it, beta=0.467, calls=12000, ESS=800, logZ=-176, logP=-377, acc=0.255, steps=2, eff=1]
# Iter: 11it [00:35,  4.44s/it, beta=0.467, calls=12400, ESS=800, logZ=-176, logP=-377, acc=0.236, steps=3, eff=1]
# Iter: 11it [00:35,  4.44s/it, beta=0.467, calls=12800, ESS=800, logZ=-176, logP=-377, acc=0.248, steps=4, eff=1]
# Iter: 12it [00:35,  4.74s/it, beta=0.467, calls=12800, ESS=800, logZ=-176, logP=-377, acc=0.248, steps=4, eff=1]
# Iter: 12it [00:35,  4.74s/it, beta=0.571, calls=12800, ESS=807, logZ=-215, logP=-377, acc=0.248, steps=4, eff=1]
# Iter: 12it [00:38,  4.74s/it, beta=0.571, calls=13200, ESS=807, logZ=-215, logP=-376, acc=0.284, steps=1, eff=1]
# Iter: 12it [00:39,  4.74s/it, beta=0.571, calls=13600, ESS=807, logZ=-215, logP=-376, acc=0.269, steps=2, eff=1]
# Iter: 12it [00:40,  4.74s/it, beta=0.571, calls=14000, ESS=807, logZ=-215, logP=-376, acc=0.196, steps=3, eff=0.984]
# Iter: 12it [00:40,  4.74s/it, beta=0.571, calls=14400, ESS=807, logZ=-215, logP=-376, acc=0.248, steps=4, eff=0.989]
# Iter: 12it [00:41,  4.74s/it, beta=0.571, calls=14800, ESS=807, logZ=-215, logP=-376, acc=0.242, steps=5, eff=0.991]
# Iter: 13it [00:41,  5.08s/it, beta=0.571, calls=14800, ESS=807, logZ=-215, logP=-376, acc=0.242, steps=5, eff=0.991]
# Iter: 13it [00:41,  5.08s/it, beta=0.678, calls=14800, ESS=806, logZ=-254, logP=-376, acc=0.242, steps=5, eff=0.991]
# Iter: 13it [00:45,  5.08s/it, beta=0.678, calls=15200, ESS=806, logZ=-254, logP=-374, acc=0.282, steps=1, eff=1]
# Iter: 13it [00:46,  5.08s/it, beta=0.678, calls=15600, ESS=806, logZ=-254, logP=-374, acc=0.236, steps=2, eff=1]
# Iter: 13it [00:47,  5.08s/it, beta=0.678, calls=16000, ESS=806, logZ=-254, logP=-374, acc=0.23, steps=3, eff=0.998]
# Iter: 13it [00:47,  5.08s/it, beta=0.678, calls=16400, ESS=806, logZ=-254, logP=-375, acc=0.205, steps=4, eff=0.988]
# Iter: 13it [00:48,  5.08s/it, beta=0.678, calls=16800, ESS=806, logZ=-254, logP=-375, acc=0.186, steps=5, eff=0.973]
# Iter: 14it [00:48,  5.68s/it, beta=0.678, calls=16800, ESS=806, logZ=-254, logP=-375, acc=0.186, steps=5, eff=0.973]
# Iter: 14it [00:48,  5.68s/it, beta=0.796, calls=16800, ESS=798, logZ=-298, logP=-375, acc=0.186, steps=5, eff=0.973]
# Iter: 14it [00:54,  5.68s/it, beta=0.796, calls=17200, ESS=798, logZ=-298, logP=-373, acc=0.323, steps=1, eff=1]
# Iter: 14it [00:55,  5.68s/it, beta=0.796, calls=17600, ESS=798, logZ=-298, logP=-373, acc=0.26, steps=2, eff=1]
# Iter: 14it [00:56,  5.68s/it, beta=0.796, calls=18000, ESS=798, logZ=-298, logP=-373, acc=0.262, steps=3, eff=1]
# Iter: 14it [00:57,  5.68s/it, beta=0.796, calls=18400, ESS=798, logZ=-298, logP=-373, acc=0.215, steps=4, eff=0.993]
# Iter: 14it [00:58,  5.68s/it, beta=0.796, calls=18800, ESS=798, logZ=-298, logP=-373, acc=0.188, steps=5, eff=0.979]
# Iter: 15it [00:58,  6.87s/it, beta=0.796, calls=18800, ESS=798, logZ=-298, logP=-373, acc=0.188, steps=5, eff=0.979]
# Iter: 15it [00:58,  6.87s/it, beta=0.924, calls=18800, ESS=794, logZ=-344, logP=-373, acc=0.188, steps=5, eff=0.979]
# Iter: 15it [01:04,  6.87s/it, beta=0.924, calls=19200, ESS=794, logZ=-344, logP=-371, acc=0.31, steps=1, eff=1]
# Iter: 15it [01:05,  6.87s/it, beta=0.924, calls=19600, ESS=794, logZ=-344, logP=-371, acc=0.226, steps=2, eff=0.996]
# Iter: 15it [01:05,  6.87s/it, beta=0.924, calls=2e+4, ESS=794, logZ=-344, logP=-371, acc=0.256, steps=3, eff=1]
# Iter: 15it [01:06,  6.87s/it, beta=0.924, calls=20400, ESS=794, logZ=-344, logP=-371, acc=0.219, steps=4, eff=0.995]
# Iter: 15it [01:07,  6.87s/it, beta=0.924, calls=20800, ESS=794, logZ=-344, logP=-371, acc=0.235, steps=5, eff=0.995]
# Iter: 16it [01:07,  7.50s/it, beta=0.924, calls=20800, ESS=794, logZ=-344, logP=-371, acc=0.235, steps=5, eff=0.995]
# Iter: 16it [01:07,  7.50s/it, beta=1, calls=20800, ESS=1040, logZ=-372, logP=-371, acc=0.235, steps=5, eff=0.995]
# Iter: 16it [01:12,  7.50s/it, beta=1, calls=21200, ESS=1040, logZ=-372, logP=-370, acc=0.318, steps=1, eff=1]
# Iter: 16it [01:12,  7.50s/it, beta=1, calls=21600, ESS=1040, logZ=-372, logP=-370, acc=0.295, steps=2, eff=1]
# Iter: 16it [01:13,  7.50s/it, beta=1, calls=22000, ESS=1040, logZ=-372, logP=-370, acc=0.279, steps=3, eff=1]
# Iter: 16it [01:14,  7.50s/it, beta=1, calls=22400, ESS=1040, logZ=-372, logP=-370, acc=0.258, steps=4, eff=1]
# Iter: 17it [01:14,  7.40s/it, beta=1, calls=22400, ESS=1040, logZ=-372, logP=-370, acc=0.258, steps=4, eff=1]
# Iter: 17it [01:14,  7.40s/it, beta=1, calls=22400, ESS=1557, logZ=-372, logP=-370, acc=0.258, steps=4, eff=1]
# Iter: 17it [01:22,  7.40s/it, beta=1, calls=22800, ESS=1557, logZ=-372, logP=-370, acc=0.357, steps=1, eff=1]
# Iter: 17it [01:22,  7.40s/it, beta=1, calls=23200, ESS=1557, logZ=-372, logP=-370, acc=0.341, steps=2, eff=1]
# Iter: 17it [01:23,  7.40s/it, beta=1, calls=23600, ESS=1557, logZ=-372, logP=-370, acc=0.307, steps=3, eff=1]
# Iter: 17it [01:25,  7.40s/it, beta=1, calls=24000, ESS=1557, logZ=-372, logP=-370, acc=0.277, steps=4, eff=1]
# Iter: 18it [01:25,  8.37s/it, beta=1, calls=24000, ESS=1557, logZ=-372, logP=-370, acc=0.277, steps=4, eff=1]
# Iter: 18it [01:25,  8.37s/it, beta=1, calls=24000, ESS=2041, logZ=-372, logP=-370, acc=0.277, steps=4, eff=1]
# Iter: 18it [01:30,  8.37s/it, beta=1, calls=24400, ESS=2041, logZ=-372, logP=-370, acc=0.336, steps=1, eff=1]
# Iter: 18it [01:32,  8.37s/it, beta=1, calls=24800, ESS=2041, logZ=-372, logP=-370, acc=0.333, steps=2, eff=1]
# Iter: 18it [01:33,  8.37s/it, beta=1, calls=25200, ESS=2041, logZ=-372, logP=-370, acc=0.297, steps=3, eff=1]
# Iter: 18it [01:34,  8.37s/it, beta=1, calls=25600, ESS=2041, logZ=-372, logP=-370, acc=0.276, steps=4, eff=1]
# Iter: 18it [01:34,  8.37s/it, beta=1, calls=26000, ESS=2041, logZ=-372, logP=-370, acc=0.292, steps=5, eff=1]
# Iter: 18it [01:36,  8.37s/it, beta=1, calls=26400, ESS=2041, logZ=-372, logP=-370, acc=0.273, steps=6, eff=1]
# Iter: 18it [01:37,  8.37s/it, beta=1, calls=26800, ESS=2041, logZ=-372, logP=-370, acc=0.267, steps=7, eff=1]
# Iter: 18it [01:38,  8.37s/it, beta=1, calls=27200, ESS=2041, logZ=-372, logP=-370, acc=0.222, steps=8, eff=0.997]
# Iter: 18it [01:39,  8.37s/it, beta=1, calls=27600, ESS=2041, logZ=-372, logP=-370, acc=0.241, steps=9, eff=0.999]
# Iter: 18it [01:40,  8.37s/it, beta=1, calls=28000, ESS=2041, logZ=-372, logP=-370, acc=0.244, steps=10, eff=1]
# Iter: 19it [01:40, 10.55s/it, beta=1, calls=28000, ESS=2041, logZ=-372, logP=-370, acc=0.244, steps=10, eff=1]
# Iter: 19it [01:40, 10.55s/it, beta=1, calls=28000, ESS=2508, logZ=-372, logP=-370, acc=0.244, steps=10, eff=1]
# Iter: 19it [01:45, 10.55s/it, beta=1, calls=28400, ESS=2508, logZ=-372, logP=-370, acc=0.377, steps=1, eff=1]
# Iter: 19it [01:45, 10.55s/it, beta=1, calls=28800, ESS=2508, logZ=-372, logP=-370, acc=0.323, steps=2, eff=1]
# Iter: 19it [01:46, 10.55s/it, beta=1, calls=29200, ESS=2508, logZ=-372, logP=-370, acc=0.27, steps=3, eff=1]
# Iter: 19it [01:46, 10.55s/it, beta=1, calls=29600, ESS=2508, logZ=-372, logP=-370, acc=0.337, steps=4, eff=1]
# Iter: 19it [01:47, 10.55s/it, beta=1, calls=3e+4, ESS=2508, logZ=-372, logP=-370, acc=0.272, steps=5, eff=1]
# Iter: 19it [01:48, 10.55s/it, beta=1, calls=30400, ESS=2508, logZ=-372, logP=-370, acc=0.287, steps=6, eff=1]
# Iter: 20it [01:48,  9.63s/it, beta=1, calls=30400, ESS=2508, logZ=-372, logP=-370, acc=0.287, steps=6, eff=1]
# Iter: 20it [01:48,  9.63s/it, beta=1, calls=30400, ESS=2960, logZ=-372, logP=-370, acc=0.287, steps=6, eff=1]
# Iter: 20it [01:51,  9.63s/it, beta=1, calls=30800, ESS=2960, logZ=-372, logP=-370, acc=0.301, steps=1, eff=1]
# Iter: 20it [01:52,  9.63s/it, beta=1, calls=31200, ESS=2960, logZ=-372, logP=-370, acc=0.352, steps=2, eff=1]
# Iter: 20it [01:53,  9.63s/it, beta=1, calls=31600, ESS=2960, logZ=-372, logP=-370, acc=0.319, steps=3, eff=1]
# Iter: 20it [01:53,  9.63s/it, beta=1, calls=32000, ESS=2960, logZ=-372, logP=-370, acc=0.291, steps=4, eff=1]
# Iter: 20it [01:54,  9.63s/it, beta=1, calls=32400, ESS=2960, logZ=-372, logP=-370, acc=0.262, steps=5, eff=1]
# Iter: 20it [01:54,  9.63s/it, beta=1, calls=32800, ESS=2960, logZ=-372, logP=-370, acc=0.256, steps=6, eff=1]
# Iter: 20it [01:55,  9.63s/it, beta=1, calls=33200, ESS=2960, logZ=-372, logP=-370, acc=0.24, steps=7, eff=1]
# Iter: 21it [01:55,  8.99s/it, beta=1, calls=33200, ESS=2960, logZ=-372, logP=-370, acc=0.24, steps=7, eff=1]
# Iter: 21it [01:55,  8.99s/it, beta=1, calls=33200, ESS=3407, logZ=-372, logP=-370, acc=0.24, steps=7, eff=1]
# Iter: 21it [02:02,  8.99s/it, beta=1, calls=33600, ESS=3407, logZ=-372, logP=-370, acc=0.348, steps=1, eff=1]
# Iter: 21it [02:03,  8.99s/it, beta=1, calls=34000, ESS=3407, logZ=-372, logP=-370, acc=0.329, steps=2, eff=1]
# Iter: 21it [02:04,  8.99s/it, beta=1, calls=34400, ESS=3407, logZ=-372, logP=-370, acc=0.305, steps=3, eff=1]
# Iter: 21it [02:04,  8.99s/it, beta=1, calls=34800, ESS=3407, logZ=-372, logP=-370, acc=0.299, steps=4, eff=1]
# Iter: 21it [02:05,  8.99s/it, beta=1, calls=35200, ESS=3407, logZ=-372, logP=-370, acc=0.273, steps=5, eff=1]
# Iter: 21it [02:06,  8.99s/it, beta=1, calls=35600, ESS=3407, logZ=-372, logP=-370, acc=0.296, steps=6, eff=1]
# Iter: 21it [02:06,  8.99s/it, beta=1, calls=36000, ESS=3407, logZ=-372, logP=-370, acc=0.26, steps=7, eff=1]
# Iter: 21it [02:07,  8.99s/it, beta=1, calls=36400, ESS=3407, logZ=-372, logP=-370, acc=0.263, steps=8, eff=1]
# Iter: 22it [02:07,  9.87s/it, beta=1, calls=36400, ESS=3407, logZ=-372, logP=-370, acc=0.263, steps=8, eff=1]
# Iter: 22it [02:07,  9.87s/it, beta=1, calls=36400, ESS=3852, logZ=-372, logP=-370, acc=0.263, steps=8, eff=1]
# Iter: 22it [02:12,  9.87s/it, beta=1, calls=36800, ESS=3852, logZ=-372, logP=-370, acc=0.349, steps=1, eff=1]
# Iter: 22it [02:13,  9.87s/it, beta=1, calls=37200, ESS=3852, logZ=-372, logP=-370, acc=0.321, steps=2, eff=1]
# Iter: 22it [02:14,  9.87s/it, beta=1, calls=37600, ESS=3852, logZ=-372, logP=-370, acc=0.302, steps=3, eff=1]
# Iter: 22it [02:14,  9.87s/it, beta=1, calls=38000, ESS=3852, logZ=-372, logP=-370, acc=0.264, steps=4, eff=1]
# Iter: 22it [02:15,  9.87s/it, beta=1, calls=38400, ESS=3852, logZ=-372, logP=-370, acc=0.312, steps=5, eff=1]
# Iter: 22it [02:16,  9.87s/it, beta=1, calls=38800, ESS=3852, logZ=-372, logP=-370, acc=0.289, steps=6, eff=1]
# Iter: 22it [02:17,  9.87s/it, beta=1, calls=39200, ESS=3852, logZ=-372, logP=-370, acc=0.313, steps=7, eff=1]
# Iter: 22it [02:18,  9.87s/it, beta=1, calls=39600, ESS=3852, logZ=-372, logP=-370, acc=0.25, steps=8, eff=1]
# Iter: 22it [02:19,  9.87s/it, beta=1, calls=4e+4, ESS=3852, logZ=-372, logP=-370, acc=0.288, steps=9, eff=1]
# Iter: 22it [02:20,  9.87s/it, beta=1, calls=40400, ESS=3852, logZ=-372, logP=-370, acc=0.256, steps=10, eff=1]
# Iter: 22it [02:21,  9.87s/it, beta=1, calls=40800, ESS=3852, logZ=-372, logP=-370, acc=0.252, steps=11, eff=1]
# Iter: 23it [02:21, 10.93s/it, beta=1, calls=40800, ESS=3852, logZ=-372, logP=-370, acc=0.252, steps=11, eff=1]
# Iter: 23it [02:21, 10.93s/it, beta=1, calls=40800, ESS=4293, logZ=-372, logP=-370, acc=0.252, steps=11, eff=1]
# Iter: 23it [02:30, 10.93s/it, beta=1, calls=41200, ESS=4293, logZ=-372, logP=-370, acc=0.387, steps=1, eff=1]
# Iter: 23it [02:30, 10.93s/it, beta=1, calls=41600, ESS=4293, logZ=-372, logP=-370, acc=0.372, steps=2, eff=1]
# Iter: 23it [02:31, 10.93s/it, beta=1, calls=42000, ESS=4293, logZ=-372, logP=-370, acc=0.353, steps=3, eff=1]
# Iter: 23it [02:32, 10.93s/it, beta=1, calls=42400, ESS=4293, logZ=-372, logP=-370, acc=0.367, steps=4, eff=1]
# Iter: 23it [02:32, 10.93s/it, beta=1, calls=42800, ESS=4293, logZ=-372, logP=-370, acc=0.344, steps=5, eff=1]
# Iter: 23it [02:33, 10.93s/it, beta=1, calls=43200, ESS=4293, logZ=-372, logP=-370, acc=0.349, steps=6, eff=1]
# Iter: 23it [02:34, 10.93s/it, beta=1, calls=43600, ESS=4293, logZ=-372, logP=-370, acc=0.282, steps=7, eff=1]
# Iter: 23it [02:34, 10.93s/it, beta=1, calls=44000, ESS=4293, logZ=-372, logP=-370, acc=0.337, steps=8, eff=1]
# Iter: 23it [02:35, 10.93s/it, beta=1, calls=44400, ESS=4293, logZ=-372, logP=-370, acc=0.305, steps=9, eff=1]
# Iter: 23it [02:36, 10.93s/it, beta=1, calls=44800, ESS=4293, logZ=-372, logP=-370, acc=0.308, steps=10, eff=1]
# Iter: 23it [02:37, 10.93s/it, beta=1, calls=45200, ESS=4293, logZ=-372, logP=-370, acc=0.276, steps=11, eff=1]
# Iter: 23it [02:37, 10.93s/it, beta=1, calls=45600, ESS=4293, logZ=-372, logP=-370, acc=0.311, steps=12, eff=1]
# Iter: 23it [02:38, 10.93s/it, beta=1, calls=46000, ESS=4293, logZ=-372, logP=-370, acc=0.303, steps=13, eff=1]
# Iter: 24it [02:38, 12.87s/it, beta=1, calls=46000, ESS=4293, logZ=-372, logP=-370, acc=0.303, steps=13, eff=1]
# Iter: 24it [02:38, 12.87s/it, beta=1, calls=46000, ESS=4731, logZ=-372, logP=-370, acc=0.303, steps=13, eff=1]
# Iter: 24it [02:43, 12.87s/it, beta=1, calls=46400, ESS=4731, logZ=-372, logP=-370, acc=0.382, steps=1, eff=1]
# Iter: 24it [02:44, 12.87s/it, beta=1, calls=46800, ESS=4731, logZ=-372, logP=-370, acc=0.367, steps=2, eff=1]
# Iter: 24it [02:45, 12.87s/it, beta=1, calls=47200, ESS=4731, logZ=-372, logP=-370, acc=0.328, steps=3, eff=1]
# Iter: 24it [02:45, 12.87s/it, beta=1, calls=47600, ESS=4731, logZ=-372, logP=-370, acc=0.367, steps=4, eff=1]
# Iter: 24it [02:46, 12.87s/it, beta=1, calls=48000, ESS=4731, logZ=-372, logP=-370, acc=0.314, steps=5, eff=1]
# Iter: 24it [02:47, 12.87s/it, beta=1, calls=48400, ESS=4731, logZ=-372, logP=-370, acc=0.3, steps=6, eff=1]
# Iter: 24it [02:47, 12.87s/it, beta=1, calls=48800, ESS=4731, logZ=-372, logP=-370, acc=0.309, steps=7, eff=1]
# Iter: 24it [02:48, 12.87s/it, beta=1, calls=49200, ESS=4731, logZ=-372, logP=-370, acc=0.299, steps=8, eff=1]
# Iter: 24it [02:49, 12.87s/it, beta=1, calls=49600, ESS=4731, logZ=-372, logP=-370, acc=0.279, steps=9, eff=1]
# Iter: 24it [02:49, 12.87s/it, beta=1, calls=5e+4, ESS=4731, logZ=-372, logP=-370, acc=0.3, steps=10, eff=1]
# Iter: 24it [02:50, 12.87s/it, beta=1, calls=50400, ESS=4731, logZ=-372, logP=-370, acc=0.31, steps=11, eff=1]
# Iter: 24it [02:51, 12.87s/it, beta=1, calls=50800, ESS=4731, logZ=-372, logP=-370, acc=0.255, steps=12, eff=1]
# Iter: 24it [02:52, 12.87s/it, beta=1, calls=51200, ESS=4731, logZ=-372, logP=-370, acc=0.295, steps=13, eff=1]
# Iter: 24it [02:53, 12.87s/it, beta=1, calls=51600, ESS=4731, logZ=-372, logP=-370, acc=0.279, steps=14, eff=1]
# Iter: 24it [02:53, 12.87s/it, beta=1, calls=52000, ESS=4731, logZ=-372, logP=-370, acc=0.254, steps=15, eff=1]
# Iter: 24it [02:54, 12.87s/it, beta=1, calls=52400, ESS=4731, logZ=-372, logP=-370, acc=0.271, steps=16, eff=1]
# Iter: 24it [02:55, 12.87s/it, beta=1, calls=52800, ESS=4731, logZ=-372, logP=-370, acc=0.245, steps=17, eff=1]
# Iter: 24it [02:56, 12.87s/it, beta=1, calls=53200, ESS=4731, logZ=-372, logP=-370, acc=0.282, steps=18, eff=1]
# Iter: 24it [03:03,  7.63s/it, beta=1, calls=58200, ESS=4731, logZ=-372, logP=-370, acc=0.282, steps=18, eff=1]
# [INFO][mcmc] Generate the posterior samples ...
# [INFO][mcmc] Generate the evidence ...
# Log evidence:  -370.9391150297109
# Log evidence error:  0.11735666630631908
# [INFO][mcmc] Writing pocoMC chains to file...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({'font.size': 15})

# %%
PARAMETER_NAMES = [
    r'$m\;[\mathrm{GeV}]$',
    r'$B_G\;[\mathrm{GeV}^{-2}]$',
    r'$B_{G,{\rm q}}\;[\mathrm{GeV}^{-2}]$',
    r'$\sigma$',
    r'$N_{\rm q}$',
    r'$Q_{s}/\mu$',
    r'$m_{\rm JIMWLK}$',
    r'$\Lambda_{\rm QCD}$'
    ]

prior_ranges = [
    (0.05,3),
    (1,10),
    (0.1,3),
    (0,1.5),
    (1,10),
    (0.2,1.5),
    (0.05,3),
    (0.001,0.2)
] 

def read_pkl_file_chain_pocoMC(PATH_pklfile_chains):
    """
    data is a dictionary containing:
    - 'chain'
    - 'weights'
    - 'logl'
    - 'logp'
    - 'logz'
    - 'logz_err'
    """
    with open(PATH_pklfile_chains, 'rb') as pf:
        data = pickle.load(pf)

    return data

# %%
def plot_corner_1dataset(n_parameters,data_array,filename,real_parameters=None):
    # check the dimension of the data array
    dim = len(data_array.shape)
    if dim == 3:
        samples = data_array[:,:,:].reshape((-1,n_parameters))
    elif dim == 2:
        samples = data_array[:,:].reshape((-1,n_parameters))
    else:
        raise ValueError("The data array should have 2 or 3 dimensions")

    # Create subplots
    fig, axes = plt.subplots(n_parameters, n_parameters, figsize=(25, 25), sharex='col', sharey='row')

    # Loop over each parameter pair
    for i in range(n_parameters):
        for j in range(n_parameters):
            ax = axes[i, j]

            if i == j:
                ax = fig.add_subplot(n_parameters, n_parameters, i * n_parameters + j + 1)
                ax.hist(samples[:, i], bins=20, color='g', histtype='step', density=True)
                ax.set_yticks([])
                ax.set_yticklabels([])
                if i != n_parameters-1:
                    ax.set_xticks([])
                    ax.set_xticklabels([])
                if i == n_parameters-1:
                    ax.tick_params(axis='x', rotation=45, labelsize=10)

                # Calculate percentiles
                percentiles = np.percentile(samples[:, i], [16, 50, 84])
                median = percentiles[1]
                upper = percentiles[2] - median
                lower = median - percentiles[0]

                ax.annotate(fr'${median:.2f}_{{-{lower:.2f}}}^{{+{upper:.2f}}}$', xy=(0.5, 1.05), xycoords='axes fraction', ha='center')

                # Add a vertical line representing the real value
                if real_parameters is not None:
                    real_value = real_parameters[i]
                    ax.axvline(x=real_value, color='k', linestyle='-')

                ax.set_xlim([prior_ranges[i][0], prior_ranges[i][1]])
            # Only fill the lower triangle
            if i > j:
                ax.hist2d(samples[:, j], samples[:, i], bins=20, cmap='Greens')


            # Set labels on the lowest and leftmost plots
            if i == n_parameters - 1:
                ax.set_xlabel(PARAMETER_NAMES[j])
            if j == 0:
                ax.set_ylabel(PARAMETER_NAMES[i])

            if i < j:
                ax.axis('off')

    # Remove space between subplots
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05)

    # Remove ticks and labels for the first and last plots
    axes[0, 0].tick_params(axis='both', which='both', bottom=False, left=False, labelbottom=False, labelleft=False)
    axes[n_parameters - 1, n_parameters - 1].tick_params(axis='both', which='both', bottom=False, left=False, labelbottom=False, labelleft=False)

    # Rotate x-axis tick labels
    for ax in axes[-1]:
        ax.tick_params(axis='x', rotation=45, labelsize=10)

    # Rotate y-axis tick labels
    for ax in axes[:, 0]:
        ax.tick_params(axis='y', rotation=45, labelsize=10)

    plt.savefig(f"{filename}.pdf")

# %%
PATH_pklfile = './mcmc/chain.pkl'
RUN1_DATA = read_pkl_file_chain_pocoMC(PATH_pklfile)

# %%
plot_corner_1dataset(8,RUN1_DATA['chain'],'corner_plot',real_parameters=None)

# %%
# second method to find the maximum likelihood
from scipy import optimize
from src.mcmc import Chain

bound_min = [a[0] for a in prior_ranges]
bound_max = [b[1] for b in prior_ranges]
bounds = [(a,b) for (a,b) in zip(bound_min,bound_max)]

rslt = optimize.differential_evolution(lambda x: -mymcmc.log_likelihood(x.T), 
                                        bounds=bounds,
                                        maxiter=10000,
                                        disp=True,
                                        tol=1e-9,
                                        vectorized=True,
                                        )
print(rslt.x)

# print the MAP parameters to file
with open('MAP_parameters_JIMWLK.dat','w') as f:
    for i in range(len(rslt.x)):
        f.write(f'{PARAMETER_NAMES[i]}: {rslt.x[i]}\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_263995/3458136859.py in <module>
#       7 bounds = [(a,b) for (a,b) in zip(bound_min,bound_max)]
#       8
# ----> 9 rslt = optimize.differential_evolution(lambda x: -mymcmc.log_likelihood(x.T),
#      10                                         bounds=bounds,
#      11                                         maxiter=10000,
#
# TypeError: differential_evolution() got an unexpected keyword argument 'vectorized'
